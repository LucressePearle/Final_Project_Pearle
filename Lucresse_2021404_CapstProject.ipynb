# %%
import  pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading the dataset
df = pd.read_csv("job_descriptions.csv")

# %%
#checking the current number of rows of the dataset
len(df)
# Out:
# 215940

# %% [markdown]
# ## Data preparation
# our data previously had 1600000 rows, so we droped the last 1400000 rows and we permently set our original dataset to the new dataset with the 215940 first rows.

# %%
#dropping the last 1,400,000 rows 
#jobs_df1 = df.iloc[:-1400000]
#checking the new lenght
#len(jobs_df1)
#saving the modified dataframe to the csv file
#jobs_df1.to_csv("job_descriptions.csv", index=False)
#dropping the columns "latitude" and "longitude"
#jobs_df1 = jobs_df1.drop(columns=['latitude','longitude'])

# %%
jobs_df1.head(20)
# Out:
#               Job Id     Experience Qualifications Salary Range  \
# 0   1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1    398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2    481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3    688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4    117057806156508  1 to 12 Years            MBA    $64K-$87K
# 5    116831420231957  4 to 12 Years            MCA    $59K-$93K
# 6   1292168246729889  3 to 15 Years            PhD   $63K-$103K
# 7   1498778686197107   2 to 8 Years          M.Com   $65K-$102K
# 8   1680293940995740   2 to 9 Years            BBA   $65K-$102K
# 9    255627812588102  1 to 10 Years            BBA    $60K-$80K
# 10  2696958764033354  3 to 10 Years            BCA   $57K-$104K
# 11  1446194141960546  4 to 12 Years         B.Tech    $64K-$98K
# 12  1914121205954296  3 to 15 Years            MCA   $65K-$122K
# 13   290761760113904   1 to 8 Years          B.Com    $56K-$86K
# ...

# %%
#getting the list of columns names
col_names= list(jobs_df1)
print(col_names)
# Out:
# ['Job Id', 'Experience', 'Qualifications', 'Salary Range', 'location', 'Country', 'Work Type', 'Company Size', 'Job Posting Date', 'Preference', 'Contact Person', 'Contact', 'Job Title', 'Role', 'Job Portal', 'Job Description', 'Benefits', 'skills', 'Responsibilities', 'Company', 'Company Profile']

# %%
#dropping the columns that are not going to be use 
jobs_df1 = jobs_df1.drop(columns=['Contact','Contact Person'])

# %%
#preview of the dataset after the removal of the columns
jobs_df1.head(15)
# Out:
#               Job Id     Experience Qualifications Salary Range  \
# 0   1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1    398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2    481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3    688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4    117057806156508  1 to 12 Years            MBA    $64K-$87K
# 5    116831420231957  4 to 12 Years            MCA    $59K-$93K
# 6   1292168246729889  3 to 15 Years            PhD   $63K-$103K
# 7   1498778686197107   2 to 8 Years          M.Com   $65K-$102K
# 8   1680293940995740   2 to 9 Years            BBA   $65K-$102K
# 9    255627812588102  1 to 10 Years            BBA    $60K-$80K
# 10  2696958764033354  3 to 10 Years            BCA   $57K-$104K
# 11  1446194141960546  4 to 12 Years         B.Tech    $64K-$98K
# 12  1914121205954296  3 to 15 Years            MCA   $65K-$122K
# 13   290761760113904   1 to 8 Years          B.Com    $56K-$86K
# ...

# %%
#getting some information about the dataset 
jobs_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215940 entries, 0 to 215939
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Job Id            215940 non-null  int64
#  1   Experience        215940 non-null  object
#  2   Qualifications    215940 non-null  object
#  3   Salary Range      215940 non-null  object
#  4   location          215940 non-null  object
#  5   Country           215940 non-null  object
#  6   Work Type         215940 non-null  object
#  7   Company Size      215940 non-null  int64
#  8   Job Posting Date  215940 non-null  object
#  9   Preference        215940 non-null  object
#  10  Job Title         215940 non-null  object
#  11  Role              215940 non-null  object
#  12  Job Portal        215940 non-null  object
#  13  Job Description   215940 non-null  object
#  14  Benefits          215940 non-null  object
#  15  skills            215940 non-null  object
# ...
